# %%
"""
We use following lines because we are running on Google Colab
If you are running notebook on a local computer, you don't need this cell
"""
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow1/text_matching/snli/main')

# %%
import tensorflow as tf
print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
import numpy as np
import pprint
import logging

from pathlib import Path
# Out:
# TensorFlow Version 1.12.0
# GPU Enabled: True

# %%
def bi_lstm(x1, x2, seq_len_1, seq_len_2):
  lstm_fw = tf.contrib.rnn.LSTMBlockFusedCell(params['hidden_dim'], name='lstm_fused_fw')
  lstm_bw = tf.contrib.rnn.LSTMBlockFusedCell(params['hidden_dim'], name='lstm_fused_bw')
  lstm_bw = tf.contrib.rnn.TimeReversedFusedRNN(lstm_bw)
  
  t1 = tf.transpose(x1, [1,0,2])
  t2 = tf.transpose(x2, [1,0,2])
  
  o1_fw, _ = lstm_fw(t1, dtype=tf.float32, sequence_length=seq_len_1)
  o1_bw, _ = lstm_bw(t1, dtype=tf.float32, sequence_length=seq_len_1)
  
  o2_fw, _ = lstm_fw(t2, dtype=tf.float32, sequence_length=seq_len_2)
  o2_bw, _ = lstm_bw(t2, dtype=tf.float32, sequence_length=seq_len_2)
  
  t1 = tf.concat([o1_fw, o1_bw], -1)
  t2 = tf.concat([o2_fw, o2_bw], -1)
  
  x1_ = tf.transpose(t1, [1,0,2])
  x2_ = tf.transpose(t2, [1,0,2])
  return x1_, x2_


def masked_attention(x, align, mask, tile_len):
  pad = tf.fill(tf.shape(align), float('-inf'))
  mask = tf.tile(tf.expand_dims(mask, 1), [1, tile_len, 1])
  align = tf.where(tf.equal(mask, 0), pad, align)
  align = tf.nn.softmax(align)
  return tf.matmul(align, x)

  
def soft_align_attention(x1, x2, mask1, mask2):
  align12 = tf.matmul(x1, x2, transpose_b=True)
  align21 = tf.transpose(align12, [0,2,1])
  
  x1_ = masked_attention(x2, align12, mask2, tf.shape(x1)[1])
  x2_ = masked_attention(x1, align21, mask1, tf.shape(x2)[1])
  
  return x1_, x2_


def attention_pooling(x, masks, dense1, dense2, dropout, is_training):  
  # alignment
  align = dense2(dense1(x))
  align = tf.squeeze(align, -1)
  
  # masking
  paddings = tf.fill(tf.shape(align), float('-inf'))
  align = tf.where(tf.equal(masks, 0), paddings, align)

  # probability
  align = tf.nn.softmax(align)
  align = dropout(align, training=is_training)
  align = tf.expand_dims(align, -1)
 
  # weighted sum
  x = tf.squeeze(tf.matmul(x, align, transpose_a=True), -1)
  
  return x

# %%
def model_fn(features, labels, mode, params):
  # Flag for Dropout / Batch Norm
  is_training = (mode == tf.estimator.ModeKeys.TRAIN)
  
  
  # Receive inputs
  text1, text2 = features
  batch_sz = tf.shape(text1)[0]
  
  
  # Word Indexing
  vocab = tf.contrib.lookup.index_table_from_file(
        params['vocab_path'], num_oov_buckets=1)
  
  text1 = vocab.lookup(text1)
  text2 = vocab.lookup(text2)
  
  
  # For Masking
  seq_len1 = tf.count_nonzero(text1, 1, dtype=tf.int32)
  seq_len2 = tf.count_nonzero(text2, 1, dtype=tf.int32)
  
  mask1 = tf.sign(text1)
  mask2 = tf.sign(text2)
  
  
  # Embedding
  embedding = np.load(params['embedding_path'])
  embedding = tf.Variable(embedding, name='embedding', dtype=tf.float32)
  x1 = tf.nn.embedding_lookup(embedding, text1)
  x2 = tf.nn.embedding_lookup(embedding, text2)
  
  
  # Encoding
  dropout = tf.layers.Dropout(0.2,
                              noise_shape=(batch_sz, 1, params['hidden_dim']))
  x1 = dropout(x1, training=is_training)
  x2 = dropout(x2, training=is_training)
  
  x1, x2 = bi_lstm(x1, x2, seq_len1, seq_len2)
  
  
  # Interaction / Comparison
  x1_, x2_ = soft_align_attention(x1, x2, mask1, mask2)
  fn = lambda x, x_: tf.concat((x,
                                x_,
                                (x - x_),
                                (x * x_),), -1)
  x1 = fn(x1, x1_)
  x2 = fn(x2, x2_)
  
  dropout = tf.layers.Dropout(0.5,
                              noise_shape=(batch_sz, 1, 8*params['hidden_dim']))
  x1 = dropout(x1, training=is_training)
  x2 = dropout(x2, training=is_training)
  
  fully_connected = tf.layers.Dense(params['hidden_dim'], tf.nn.elu)
  x1 = fully_connected(x1)
  x2 = fully_connected(x2)
  
  
  # Encoding on top of Interaction
  dropout = tf.layers.Dropout(0.2,
                              noise_shape=(batch_sz, 1, params['hidden_dim']))
  x1 = dropout(x1, training=is_training)
  x2 = dropout(x2, training=is_training)
  
  x1, x2 = bi_lstm(x1, x2, seq_len1, seq_len2)
  
  
  # Extraction
  attn1 = tf.layers.Dense(params['hidden_dim'], tf.tanh, use_bias=False, name='attn_pool_1')
  attn2 = tf.layers.Dense(1, use_bias=False, name='attn_pool_2')
  dropout = tf.layers.Dropout(0.15)
  
  x = tf.concat((
      attention_pooling(x1, mask1, attn1, attn2, dropout, is_training),
      attention_pooling(x2, mask2, attn1, attn2, dropout, is_training),
      tf.reduce_max(x1, 1),
      tf.reduce_max(x2, 1),
  ), -1)
  
  
  # Fully Connected
  x = tf.layers.dropout(x, 0.5, training=is_training)
  
  x = tf.layers.dense(x, params['hidden_dim'], tf.nn.elu, name='fully_connected_1')
  
  x = tf.layers.dropout(x, 0.2, training=is_training)
  
  x = tf.layers.dense(x, params['hidden_dim'], tf.nn.elu, name='fully_connected_2')
  
  x = tf.layers.dropout(x, 0.2, training=is_training)
  
  logits = tf.layers.dense(x, params['num_labels'], name='output')
  
  
  if mode == tf.estimator.ModeKeys.PREDICT:
    return tf.estimator.EstimatorSpec(mode=mode,
                                      predictions=tf.argmax(logits, -1))
  else:
    loss_op = tf.nn.sparse_softmax_cross_entropy_with_logits(
      labels=labels, logits=logits)
    loss_op = tf.reduce_mean(loss_op)
  
  
  if mode == tf.estimator.ModeKeys.TRAIN:
    variables = tf.trainable_variables()
    tf.logging.info('\n'+pprint.pformat(variables))
    
    grads = tf.gradients(loss_op, variables)
    grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    
    global_step=tf.train.get_or_create_global_step()
    decay_lr = tf.train.exponential_decay(
        params['lr'], global_step, 100000, .25)
    
    optim = tf.train.AdamOptimizer(decay_lr)
    
    train_op = optim.apply_gradients(
      zip(grads, variables), global_step=global_step)
    
    hook = tf.train.LoggingTensorHook({'lr': decay_lr}, every_n_iter=100)
    
    return tf.estimator.EstimatorSpec(mode=mode,
                                      loss=loss_op,
                                      train_op=train_op,
                                      training_hooks=[hook],)
  
  
  if mode == tf.estimator.ModeKeys.EVAL:
    acc_op = tf.metrics.accuracy(labels=labels,
                                 predictions=tf.argmax(logits, -1))
    
    return tf.estimator.EstimatorSpec(mode=mode,
                                      loss=loss_op,
                                      eval_metric_ops={'acc': acc_op})

# %%
# stream data from text files
def gen_fn(f_path):
  label2idx = {'neutral': 0, 'entailment': 1, 'contradiction': 2,}
  with open(f_path) as f:
    print('Reading', f_path)
    for line in f:
      line = line.rstrip()
      label, text1, text2 = line.split('\t')
      if label == '-':
        continue
      yield (text1.split(), text2.split()), label2idx[label]
      

def input_fn(mode, params):
  _shapes = (([None], [None]), ())
  _types = ((tf.string, tf.string), tf.int32)
  _pads = (('<pad>', '<pad>'), -1)
  
  if mode == tf.estimator.ModeKeys.TRAIN:
    ds = tf.data.Dataset.from_generator(
      lambda: gen_fn(params['train_path'],),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['num_samples'])
    ds = ds.repeat()
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
  
  if mode == tf.estimator.ModeKeys.EVAL:
    ds = tf.data.Dataset.from_generator(
      lambda: gen_fn(params['test_path'],),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
  
  return ds

# %%
params = {
    'model_dir': '../model/esim',
    'log_path': '../log/esim.txt',
    'train_path': '../data/train.txt',
    'test_path': '../data/test.txt',
    'embedding_path': '../vocab/word.npy',
    'vocab_path': '../vocab/word.txt',
    'batch_size': 32,
    'num_samples': 550152,
    'hidden_dim': 300,
    'lr': 4e-4,
    'clip_norm': 10.,
    'num_labels': 3,
    'num_patience': 7,
}

# %%
# Create directory if not exist
Path(os.path.dirname(params['log_path'])).mkdir(exist_ok=True)
Path(params['model_dir']).mkdir(exist_ok=True, parents=True)

# Logging
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)
fh = logging.FileHandler(params['log_path'])
logger.addHandler(fh)

# Create an estimator
_eval_steps = params['num_samples']//params['batch_size']//10
config = tf.estimator.RunConfig(
  save_checkpoints_steps=_eval_steps,
  keep_checkpoint_max=params['num_patience']+2,)

estimator = tf.estimator.Estimator(
  model_fn=model_fn,
  model_dir=params['model_dir'],
  config=config,
  params=params)

# This hook early-stops model if testing loss is not decreased
hook = tf.contrib.estimator.stop_if_no_decrease_hook(
  estimator=estimator,
  metric_name='loss',
  max_steps_without_decrease=params['num_patience']*_eval_steps,
  run_every_secs=None,
  run_every_steps=_eval_steps)

# Train on training data and Evaluate on testing data
train_spec = tf.estimator.TrainSpec(
  input_fn=lambda: input_fn(mode=tf.estimator.ModeKeys.TRAIN,
                            params=params),
  hooks=[hook])

eval_spec = tf.estimator.EvalSpec(
  input_fn=lambda: input_fn(mode=tf.estimator.ModeKeys.EVAL,
                            params=params),
  steps=None,
  throttle_secs=60,)

tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': '../model/esim', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 1719, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 9, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe5908f1588>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 1719 or save_checkpoints_secs None.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'embedding:0' shape=(20884, 300) dtype=float32_ref>,
#  <tf.Variable 'lstm_fused_fw/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'lstm_fused_fw/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'lstm_fused_bw/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'lstm_fused_bw/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(2400, 300) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'lstm_fused_fw_1/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'lstm_fused_fw_1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'lstm_fused_bw_1/kernel:0' shape=(600, 1200) dtype=float32_ref>,
#  <tf.Variable 'lstm_fused_bw_1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'attn_pool_1/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'attn_pool_2/kernel:0' shape=(300, 1) dtype=float32_ref>,
#  <tf.Variable 'fully_connected_1/kernel:0' shape=(2400, 300) dtype=float32_ref>,
#  <tf.Variable 'fully_connected_1/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'fully_connected_2/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'fully_connected_2/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'output/kernel:0' shape=(300, 3) dtype=float32_ref>,
#  <tf.Variable 'output/bias:0' shape=(3,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ../model/esim/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 1.0886979, step = 0
# INFO:tensorflow:lr = 0.0004
# INFO:tensorflow:global_step/sec: 6.95293
# INFO:tensorflow:loss = 1.0343503, step = 100 (14.388 sec)
# INFO:tensorflow:lr = 0.00039944582 (14.394 sec)
# INFO:tensorflow:global_step/sec: 7.13766
# INFO:tensorflow:loss = 0.84531313, step = 200 (14.008 sec)
# INFO:tensorflow:lr = 0.0003988925 (14.006 sec)
# INFO:tensorflow:global_step/sec: 7.2597
# INFO:tensorflow:loss = 1.0646458, step = 300 (13.775 sec)
# INFO:tensorflow:lr = 0.00039833988 (13.774 sec)
# INFO:tensorflow:global_step/sec: 7.20674
# INFO:tensorflow:loss = 0.9282912, step = 400 (13.879 sec)
# INFO:tensorflow:lr = 0.00039778807 (13.877 sec)
# INFO:tensorflow:global_step/sec: 7.00696
# INFO:tensorflow:loss = 0.96268153, step = 500 (14.267 sec)
# INFO:tensorflow:lr = 0.00039723696 (14.270 sec)
# INFO:tensorflow:global_step/sec: 7.13691
# INFO:tensorflow:loss = 0.7815474, step = 600 (14.016 sec)
# INFO:tensorflow:lr = 0.00039668666 (14.014 sec)
# INFO:tensorflow:global_step/sec: 7.17964
# INFO:tensorflow:loss = 0.71958435, step = 700 (13.927 sec)
# INFO:tensorflow:lr = 0.00039613713 (13.928 sec)
# INFO:tensorflow:global_step/sec: 7.1188
# INFO:tensorflow:loss = 0.93845665, step = 800 (14.049 sec)
# INFO:tensorflow:lr = 0.00039558837 (14.047 sec)
# INFO:tensorflow:global_step/sec: 7.07993
# INFO:tensorflow:loss = 1.0399328, step = 900 (14.124 sec)
# INFO:tensorflow:lr = 0.00039504035 (14.127 sec)
# INFO:tensorflow:global_step/sec: 7.02045
# INFO:tensorflow:loss = 0.9327405, step = 1000 (14.239 sec)
# INFO:tensorflow:lr = 0.00039449305 (14.236 sec)
# INFO:tensorflow:global_step/sec: 7.00505
# INFO:tensorflow:loss = 0.8310672, step = 1100 (14.279 sec)
# INFO:tensorflow:lr = 0.00039394654 (14.278 sec)
# INFO:tensorflow:global_step/sec: 7.07744
# INFO:tensorflow:loss = 0.9250527, step = 1200 (14.125 sec)
# INFO:tensorflow:lr = 0.0003934008 (14.125 sec)
# INFO:tensorflow:global_step/sec: 7.15266
# INFO:tensorflow:loss = 0.7546134, step = 1300 (13.985 sec)
# INFO:tensorflow:lr = 0.0003928558 (13.987 sec)
# INFO:tensorflow:global_step/sec: 7.11864
# INFO:tensorflow:loss = 0.7383088, step = 1400 (14.049 sec)
# INFO:tensorflow:lr = 0.00039231157 (14.049 sec)
# INFO:tensorflow:global_step/sec: 7.05217
# INFO:tensorflow:loss = 0.6950554, step = 1500 (14.175 sec)
# INFO:tensorflow:lr = 0.0003917681 (14.180 sec)
# INFO:tensorflow:global_step/sec: 7.25908
# INFO:tensorflow:loss = 0.89817977, step = 1600 (13.777 sec)
# INFO:tensorflow:lr = 0.0003912254 (13.774 sec)
# INFO:tensorflow:global_step/sec: 6.95483
# INFO:tensorflow:loss = 0.9493547, step = 1700 (14.377 sec)
# INFO:tensorflow:lr = 0.00039068342 (14.381 sec)
# INFO:tensorflow:Saving checkpoints for 1719 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-02:25:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-1719
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-02:26:11
# INFO:tensorflow:Saving dict for global step 1719: acc = 0.70734936, global_step = 1719, loss = 0.7195825
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1719: ../model/esim/model.ckpt-1719
# INFO:tensorflow:global_step/sec: 3.3808
# INFO:tensorflow:loss = 0.84880966, step = 1800 (29.580 sec)
# INFO:tensorflow:lr = 0.00039014217 (29.579 sec)
# INFO:tensorflow:global_step/sec: 7.03654
# INFO:tensorflow:loss = 0.8616847, step = 1900 (14.213 sec)
# INFO:tensorflow:lr = 0.0003896017 (14.209 sec)
# INFO:tensorflow:global_step/sec: 7.03885
# INFO:tensorflow:loss = 0.6893368, step = 2000 (14.206 sec)
# INFO:tensorflow:lr = 0.00038906196 (14.207 sec)
# INFO:tensorflow:global_step/sec: 7.1681
# INFO:tensorflow:loss = 0.67004704, step = 2100 (13.953 sec)
# INFO:tensorflow:lr = 0.00038852298 (13.954 sec)
# INFO:tensorflow:global_step/sec: 7.02258
# INFO:tensorflow:loss = 0.7576257, step = 2200 (14.235 sec)
# INFO:tensorflow:lr = 0.00038798474 (14.234 sec)
# INFO:tensorflow:global_step/sec: 6.96296
# INFO:tensorflow:loss = 0.76270896, step = 2300 (14.361 sec)
# INFO:tensorflow:lr = 0.00038744727 (14.362 sec)
# INFO:tensorflow:global_step/sec: 7.06433
# INFO:tensorflow:loss = 0.85807514, step = 2400 (14.161 sec)
# INFO:tensorflow:lr = 0.0003869105 (14.158 sec)
# INFO:tensorflow:global_step/sec: 7.04604
# INFO:tensorflow:loss = 0.76681364, step = 2500 (14.190 sec)
# INFO:tensorflow:lr = 0.0003863745 (14.189 sec)
# INFO:tensorflow:global_step/sec: 7.02157
# INFO:tensorflow:loss = 0.8385766, step = 2600 (14.239 sec)
# INFO:tensorflow:lr = 0.00038583926 (14.240 sec)
# INFO:tensorflow:global_step/sec: 6.93845
# INFO:tensorflow:loss = 0.843351, step = 2700 (14.419 sec)
# INFO:tensorflow:lr = 0.00038530474 (14.419 sec)
# INFO:tensorflow:global_step/sec: 7.2441
# INFO:tensorflow:loss = 0.81016827, step = 2800 (13.797 sec)
# INFO:tensorflow:lr = 0.00038477094 (13.802 sec)
# INFO:tensorflow:global_step/sec: 6.88454
# INFO:tensorflow:loss = 0.78735507, step = 2900 (14.531 sec)
# INFO:tensorflow:lr = 0.00038423794 (14.526 sec)
# INFO:tensorflow:global_step/sec: 7.08908
# INFO:tensorflow:loss = 0.66230416, step = 3000 (14.105 sec)
# INFO:tensorflow:lr = 0.00038370563 (14.106 sec)
# INFO:tensorflow:global_step/sec: 7.005
# INFO:tensorflow:loss = 0.6055019, step = 3100 (14.278 sec)
# INFO:tensorflow:lr = 0.00038317408 (14.278 sec)
# INFO:tensorflow:global_step/sec: 7.21683
# INFO:tensorflow:loss = 0.46339, step = 3200 (13.855 sec)
# INFO:tensorflow:lr = 0.00038264325 (13.855 sec)
# INFO:tensorflow:global_step/sec: 6.9316
# INFO:tensorflow:loss = 0.7010249, step = 3300 (14.425 sec)
# INFO:tensorflow:lr = 0.00038211315 (14.425 sec)
# INFO:tensorflow:global_step/sec: 7.14386
# INFO:tensorflow:loss = 0.77125317, step = 3400 (13.999 sec)
# INFO:tensorflow:lr = 0.0003815838 (13.999 sec)
# INFO:tensorflow:Saving checkpoints for 3438 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-02:30:18
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-3438
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-02:30:29
# INFO:tensorflow:Saving dict for global step 3438: acc = 0.77565145, global_step = 3438, loss = 0.5668479
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3438: ../model/esim/model.ckpt-3438
# INFO:tensorflow:global_step/sec: 3.63029
# INFO:tensorflow:loss = 0.66001177, step = 3500 (27.544 sec)
# INFO:tensorflow:lr = 0.00038105517 (27.547 sec)
# INFO:tensorflow:global_step/sec: 6.85367
# INFO:tensorflow:loss = 0.6094793, step = 3600 (14.588 sec)
# INFO:tensorflow:lr = 0.0003805273 (14.586 sec)
# INFO:tensorflow:global_step/sec: 7.13002
# INFO:tensorflow:loss = 0.5037739, step = 3700 (14.032 sec)
# INFO:tensorflow:lr = 0.0003800001 (14.030 sec)
# INFO:tensorflow:global_step/sec: 7.02884
# INFO:tensorflow:loss = 0.74367875, step = 3800 (14.227 sec)
# INFO:tensorflow:lr = 0.0003794737 (14.228 sec)
# INFO:tensorflow:global_step/sec: 7.04354
# INFO:tensorflow:loss = 0.45845258, step = 3900 (14.191 sec)
# INFO:tensorflow:lr = 0.00037894803 (14.197 sec)
# INFO:tensorflow:global_step/sec: 7.18022
# INFO:tensorflow:loss = 0.6325846, step = 4000 (13.934 sec)
# INFO:tensorflow:lr = 0.00037842305 (13.928 sec)
# INFO:tensorflow:global_step/sec: 7.29442
# INFO:tensorflow:loss = 0.5797474, step = 4100 (13.702 sec)
# INFO:tensorflow:lr = 0.00037789883 (13.702 sec)
# INFO:tensorflow:global_step/sec: 7.21038
# INFO:tensorflow:loss = 0.80096906, step = 4200 (13.875 sec)
# INFO:tensorflow:lr = 0.00037737528 (13.876 sec)
# INFO:tensorflow:global_step/sec: 6.90638
# INFO:tensorflow:loss = 0.4719336, step = 4300 (14.475 sec)
# INFO:tensorflow:lr = 0.0003768525 (14.474 sec)
# INFO:tensorflow:global_step/sec: 6.87927
# INFO:tensorflow:loss = 0.5436519, step = 4400 (14.540 sec)
# INFO:tensorflow:lr = 0.00037633043 (14.541 sec)
# INFO:tensorflow:global_step/sec: 7.1972
# INFO:tensorflow:loss = 0.73569536, step = 4500 (13.894 sec)
# INFO:tensorflow:lr = 0.0003758091 (13.892 sec)
# INFO:tensorflow:global_step/sec: 6.9766
# INFO:tensorflow:loss = 0.71619356, step = 4600 (14.334 sec)
# INFO:tensorflow:lr = 0.00037528848 (14.335 sec)
# INFO:tensorflow:global_step/sec: 6.98972
# INFO:tensorflow:loss = 0.6129996, step = 4700 (14.301 sec)
# INFO:tensorflow:lr = 0.00037476854 (14.304 sec)
# INFO:tensorflow:global_step/sec: 7.08314
# INFO:tensorflow:loss = 0.5703119, step = 4800 (14.122 sec)
# INFO:tensorflow:lr = 0.0003742494 (14.119 sec)
# INFO:tensorflow:global_step/sec: 7.1065
# INFO:tensorflow:loss = 0.7259691, step = 4900 (14.068 sec)
# INFO:tensorflow:lr = 0.0003737309 (14.074 sec)
# INFO:tensorflow:global_step/sec: 7.00321
# INFO:tensorflow:loss = 0.54963315, step = 5000 (14.287 sec)
# INFO:tensorflow:lr = 0.00037321317 (14.279 sec)
# INFO:tensorflow:global_step/sec: 7.13265
# INFO:tensorflow:loss = 0.5909512, step = 5100 (14.013 sec)
# INFO:tensorflow:lr = 0.00037269611 (14.013 sec)
# INFO:tensorflow:Saving checkpoints for 5157 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-02:34:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-5157
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-02:34:46
# INFO:tensorflow:Saving dict for global step 5157: acc = 0.7990635, global_step = 5157, loss = 0.5077126
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5157: ../model/esim/model.ckpt-5157
# INFO:tensorflow:global_step/sec: 3.61239
# INFO:tensorflow:loss = 0.44679856, step = 5200 (27.687 sec)
# INFO:tensorflow:lr = 0.00037217984 (27.688 sec)
# INFO:tensorflow:global_step/sec: 7.13067
# INFO:tensorflow:loss = 0.56958234, step = 5300 (14.026 sec)
# INFO:tensorflow:lr = 0.00037166424 (14.026 sec)
# INFO:tensorflow:global_step/sec: 7.09193
# INFO:tensorflow:loss = 0.7359562, step = 5400 (14.100 sec)
# INFO:tensorflow:lr = 0.0003711494 (14.102 sec)
# INFO:tensorflow:global_step/sec: 6.99737
# INFO:tensorflow:loss = 0.54518497, step = 5500 (14.288 sec)
# INFO:tensorflow:lr = 0.0003706352 (14.287 sec)
# INFO:tensorflow:global_step/sec: 6.9721
# INFO:tensorflow:loss = 0.70455813, step = 5600 (14.342 sec)
# INFO:tensorflow:lr = 0.00037012176 (14.341 sec)
# INFO:tensorflow:global_step/sec: 6.98138
# INFO:tensorflow:loss = 0.76860803, step = 5700 (14.322 sec)
# INFO:tensorflow:lr = 0.000369609 (14.323 sec)
# INFO:tensorflow:global_step/sec: 7.03465
# INFO:tensorflow:loss = 0.5466182, step = 5800 (14.215 sec)
# INFO:tensorflow:lr = 0.000369097 (14.216 sec)
# INFO:tensorflow:global_step/sec: 7.21742
# INFO:tensorflow:loss = 0.540011, step = 5900 (13.861 sec)
# INFO:tensorflow:lr = 0.00036858566 (13.860 sec)
# INFO:tensorflow:global_step/sec: 7.09882
# INFO:tensorflow:loss = 0.38239327, step = 6000 (14.081 sec)
# INFO:tensorflow:lr = 0.00036807504 (14.081 sec)
# INFO:tensorflow:global_step/sec: 7.12598
# INFO:tensorflow:loss = 0.5972012, step = 6100 (14.040 sec)
# INFO:tensorflow:lr = 0.0003675651 (14.039 sec)
# INFO:tensorflow:global_step/sec: 7.07149
# INFO:tensorflow:loss = 0.5230027, step = 6200 (14.140 sec)
# INFO:tensorflow:lr = 0.00036705594 (14.141 sec)
# INFO:tensorflow:global_step/sec: 6.87922
# INFO:tensorflow:loss = 0.62187326, step = 6300 (14.536 sec)
# INFO:tensorflow:lr = 0.00036654744 (14.533 sec)
# INFO:tensorflow:global_step/sec: 7.15477
# INFO:tensorflow:loss = 0.49492362, step = 6400 (13.980 sec)
# INFO:tensorflow:lr = 0.00036603966 (13.980 sec)
# INFO:tensorflow:global_step/sec: 7.01762
# INFO:tensorflow:loss = 0.647176, step = 6500 (14.250 sec)
# INFO:tensorflow:lr = 0.00036553256 (14.250 sec)
# INFO:tensorflow:global_step/sec: 6.94413
# INFO:tensorflow:loss = 0.8124406, step = 6600 (14.399 sec)
# INFO:tensorflow:lr = 0.00036502618 (14.400 sec)
# INFO:tensorflow:global_step/sec: 7.26653
# INFO:tensorflow:loss = 0.53794974, step = 6700 (13.760 sec)
# INFO:tensorflow:lr = 0.0003645205 (13.760 sec)
# INFO:tensorflow:global_step/sec: 6.9488
# INFO:tensorflow:loss = 0.468285, step = 6800 (14.386 sec)
# INFO:tensorflow:lr = 0.00036401552 (14.390 sec)
# INFO:tensorflow:Saving checkpoints for 6876 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-02:38:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-6876
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-02:39:03
# INFO:tensorflow:Saving dict for global step 6876: acc = 0.80995524, global_step = 6876, loss = 0.4794062
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6876: ../model/esim/model.ckpt-6876
# INFO:tensorflow:global_step/sec: 3.59633
# INFO:tensorflow:loss = 0.5972084, step = 6900 (27.813 sec)
# INFO:tensorflow:lr = 0.00036351124 (27.809 sec)
# INFO:tensorflow:global_step/sec: 6.85798
# INFO:tensorflow:loss = 0.49633026, step = 7000 (14.581 sec)
# INFO:tensorflow:lr = 0.00036300762 (14.581 sec)
# INFO:tensorflow:global_step/sec: 7.16459
# INFO:tensorflow:loss = 0.55848384, step = 7100 (13.952 sec)
# INFO:tensorflow:lr = 0.00036250477 (13.957 sec)
# INFO:tensorflow:global_step/sec: 7.06911
# INFO:tensorflow:loss = 0.3910272, step = 7200 (14.145 sec)
# INFO:tensorflow:lr = 0.00036200258 (14.146 sec)
# INFO:tensorflow:global_step/sec: 6.99002
# INFO:tensorflow:loss = 0.79978263, step = 7300 (14.308 sec)
# INFO:tensorflow:lr = 0.0003615011 (14.303 sec)
# INFO:tensorflow:global_step/sec: 6.97021
# INFO:tensorflow:loss = 0.6158403, step = 7400 (14.345 sec)
# INFO:tensorflow:lr = 0.00036100028 (14.346 sec)
# INFO:tensorflow:global_step/sec: 7.16219
# INFO:tensorflow:loss = 0.5864039, step = 7500 (13.969 sec)
# INFO:tensorflow:lr = 0.00036050015 (13.968 sec)
# INFO:tensorflow:global_step/sec: 7.27348
# INFO:tensorflow:loss = 0.40008193, step = 7600 (13.746 sec)
# INFO:tensorflow:lr = 0.00036000073 (13.748 sec)
# INFO:tensorflow:global_step/sec: 7.04571
# INFO:tensorflow:loss = 0.5427517, step = 7700 (14.195 sec)
# INFO:tensorflow:lr = 0.00035950204 (14.193 sec)
# INFO:tensorflow:global_step/sec: 7.07834
# INFO:tensorflow:loss = 0.47888404, step = 7800 (14.128 sec)
# INFO:tensorflow:lr = 0.000359004 (14.128 sec)
# INFO:tensorflow:global_step/sec: 7.02143
# INFO:tensorflow:loss = 0.36969367, step = 7900 (14.241 sec)
# INFO:tensorflow:lr = 0.00035850666 (14.242 sec)
# INFO:tensorflow:global_step/sec: 7.10924
# INFO:tensorflow:loss = 0.78710127, step = 8000 (14.060 sec)
# INFO:tensorflow:lr = 0.00035801003 (14.059 sec)
# INFO:tensorflow:global_step/sec: 7.13726
# INFO:tensorflow:loss = 0.3969161, step = 8100 (14.016 sec)
# INFO:tensorflow:lr = 0.00035751407 (14.016 sec)
# INFO:tensorflow:global_step/sec: 7.18878
# INFO:tensorflow:loss = 0.4981129, step = 8200 (13.909 sec)
# INFO:tensorflow:lr = 0.00035701878 (13.911 sec)
# INFO:tensorflow:global_step/sec: 7.18067
# INFO:tensorflow:loss = 0.55027795, step = 8300 (13.922 sec)
# INFO:tensorflow:lr = 0.0003565242 (13.921 sec)
# INFO:tensorflow:global_step/sec: 6.99679
# INFO:tensorflow:loss = 0.49247533, step = 8400 (14.292 sec)
# INFO:tensorflow:lr = 0.00035603027 (14.293 sec)
# INFO:tensorflow:global_step/sec: 6.98962
# INFO:tensorflow:loss = 0.25967813, step = 8500 (14.314 sec)
# INFO:tensorflow:lr = 0.00035553705 (14.314 sec)
# INFO:tensorflow:Saving checkpoints for 8595 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-02:43:08
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-8595
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-02:43:20
# INFO:tensorflow:Saving dict for global step 8595: acc = 0.8196254, global_step = 8595, loss = 0.46270156
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8595: ../model/esim/model.ckpt-8595
# INFO:tensorflow:global_step/sec: 3.637
# INFO:tensorflow:loss = 0.6282748, step = 8600 (27.489 sec)
# INFO:tensorflow:lr = 0.00035504453 (27.491 sec)
# INFO:tensorflow:global_step/sec: 7.14839
# INFO:tensorflow:loss = 0.66781664, step = 8700 (13.994 sec)
# INFO:tensorflow:lr = 0.00035455267 (13.992 sec)
# INFO:tensorflow:global_step/sec: 7.07279
# INFO:tensorflow:loss = 0.46215904, step = 8800 (14.139 sec)
# INFO:tensorflow:lr = 0.00035406149 (14.139 sec)
# INFO:tensorflow:global_step/sec: 7.05424
# INFO:tensorflow:loss = 0.46990228, step = 8900 (14.176 sec)
# INFO:tensorflow:lr = 0.00035357097 (14.176 sec)
# INFO:tensorflow:global_step/sec: 7.28155
# INFO:tensorflow:loss = 0.72173965, step = 9000 (13.730 sec)
# INFO:tensorflow:lr = 0.00035308118 (13.734 sec)
# INFO:tensorflow:global_step/sec: 6.96472
# INFO:tensorflow:loss = 0.5191716, step = 9100 (14.359 sec)
# INFO:tensorflow:lr = 0.00035259206 (14.359 sec)
# INFO:tensorflow:global_step/sec: 7.21771
# INFO:tensorflow:loss = 0.4150697, step = 9200 (13.853 sec)
# INFO:tensorflow:lr = 0.0003521036 (13.854 sec)
# INFO:tensorflow:global_step/sec: 7.21861
# INFO:tensorflow:loss = 0.5886693, step = 9300 (13.855 sec)
# INFO:tensorflow:lr = 0.0003516158 (13.851 sec)
# INFO:tensorflow:global_step/sec: 6.89888
# INFO:tensorflow:loss = 0.51552445, step = 9400 (14.492 sec)
# INFO:tensorflow:lr = 0.0003511287 (14.496 sec)
# INFO:tensorflow:global_step/sec: 7.13598
# INFO:tensorflow:loss = 0.4008411, step = 9500 (14.016 sec)
# INFO:tensorflow:lr = 0.00035064228 (14.013 sec)
# INFO:tensorflow:global_step/sec: 7.11151
# INFO:tensorflow:loss = 0.8380306, step = 9600 (14.057 sec)
# INFO:tensorflow:lr = 0.00035015654 (14.061 sec)
# INFO:tensorflow:global_step/sec: 7.06544
# INFO:tensorflow:loss = 0.5385687, step = 9700 (14.160 sec)
# INFO:tensorflow:lr = 0.00034967146 (14.155 sec)
# INFO:tensorflow:global_step/sec: 6.81425
# INFO:tensorflow:loss = 0.39759886, step = 9800 (14.671 sec)
# INFO:tensorflow:lr = 0.00034918703 (14.671 sec)
# INFO:tensorflow:global_step/sec: 7.18011
# INFO:tensorflow:loss = 0.4829327, step = 9900 (13.932 sec)
# INFO:tensorflow:lr = 0.00034870327 (13.932 sec)
# INFO:tensorflow:global_step/sec: 7.11118
# INFO:tensorflow:loss = 0.5898173, step = 10000 (14.059 sec)
# INFO:tensorflow:lr = 0.00034822023 (14.060 sec)
# INFO:tensorflow:global_step/sec: 7.02034
# INFO:tensorflow:loss = 0.6156425, step = 10100 (14.245 sec)
# INFO:tensorflow:lr = 0.00034773783 (14.251 sec)
# INFO:tensorflow:global_step/sec: 7.12811
# INFO:tensorflow:loss = 0.54998964, step = 10200 (14.032 sec)
# INFO:tensorflow:lr = 0.00034725605 (14.025 sec)
# INFO:tensorflow:global_step/sec: 7.15902
# INFO:tensorflow:loss = 0.41428632, step = 10300 (13.962 sec)
# INFO:tensorflow:lr = 0.00034677502 (13.966 sec)
# INFO:tensorflow:Saving checkpoints for 10314 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-02:47:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-10314
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-02:47:36
# INFO:tensorflow:Saving dict for global step 10314: acc = 0.8312296, global_step = 10314, loss = 0.43355533
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10314: ../model/esim/model.ckpt-10314
# INFO:tensorflow:global_step/sec: 3.55321
# INFO:tensorflow:loss = 0.38005477, step = 10400 (28.149 sec)
# INFO:tensorflow:lr = 0.0003462946 (28.147 sec)
# INFO:tensorflow:global_step/sec: 7.02946
# INFO:tensorflow:loss = 0.5665464, step = 10500 (14.222 sec)
# INFO:tensorflow:lr = 0.0003458149 (14.220 sec)
# INFO:tensorflow:global_step/sec: 6.96147
# INFO:tensorflow:loss = 0.7083071, step = 10600 (14.369 sec)
# INFO:tensorflow:lr = 0.00034533584 (14.368 sec)
# INFO:tensorflow:global_step/sec: 6.85792
# INFO:tensorflow:loss = 0.82405925, step = 10700 (14.578 sec)
# INFO:tensorflow:lr = 0.0003448574 (14.579 sec)
# INFO:tensorflow:global_step/sec: 7.05763
# INFO:tensorflow:loss = 0.70492, step = 10800 (14.171 sec)
# INFO:tensorflow:lr = 0.00034437966 (14.171 sec)
# INFO:tensorflow:global_step/sec: 6.93513
# INFO:tensorflow:loss = 0.72766376, step = 10900 (14.415 sec)
# INFO:tensorflow:lr = 0.0003439026 (14.421 sec)
# INFO:tensorflow:global_step/sec: 6.87014
# INFO:tensorflow:loss = 0.42147708, step = 11000 (14.563 sec)
# INFO:tensorflow:lr = 0.00034342616 (14.556 sec)
# INFO:tensorflow:global_step/sec: 7.03186
# INFO:tensorflow:loss = 0.6497179, step = 11100 (14.219 sec)
# INFO:tensorflow:lr = 0.0003429504 (14.219 sec)
# INFO:tensorflow:global_step/sec: 7.07052
# INFO:tensorflow:loss = 0.4855424, step = 11200 (14.138 sec)
# INFO:tensorflow:lr = 0.00034247528 (14.138 sec)
# INFO:tensorflow:global_step/sec: 7.24395
# INFO:tensorflow:loss = 0.37130666, step = 11300 (13.808 sec)
# INFO:tensorflow:lr = 0.00034200086 (13.811 sec)
# INFO:tensorflow:global_step/sec: 7.18322
# INFO:tensorflow:loss = 0.52205586, step = 11400 (13.921 sec)
# INFO:tensorflow:lr = 0.00034152708 (13.919 sec)
# INFO:tensorflow:global_step/sec: 7.08271
# INFO:tensorflow:loss = 0.36474496, step = 11500 (14.123 sec)
# INFO:tensorflow:lr = 0.00034105396 (14.121 sec)
# INFO:tensorflow:global_step/sec: 6.95448
# INFO:tensorflow:loss = 0.73126996, step = 11600 (14.372 sec)
# INFO:tensorflow:lr = 0.00034058146 (14.376 sec)
# INFO:tensorflow:global_step/sec: 7.18336
# INFO:tensorflow:loss = 0.62467146, step = 11700 (13.921 sec)
# INFO:tensorflow:lr = 0.00034010966 (13.918 sec)
# INFO:tensorflow:global_step/sec: 6.94037
# INFO:tensorflow:loss = 0.3592779, step = 11800 (14.409 sec)
# INFO:tensorflow:lr = 0.0003396385 (14.414 sec)
# INFO:tensorflow:global_step/sec: 7.15925
# INFO:tensorflow:loss = 0.40743354, step = 11900 (13.967 sec)
# INFO:tensorflow:lr = 0.00033916798 (13.968 sec)
# INFO:tensorflow:global_step/sec: 7.21246
# INFO:tensorflow:loss = 0.40043014, step = 12000 (13.872 sec)
# INFO:tensorflow:lr = 0.00033869813 (13.867 sec)
# INFO:tensorflow:Saving checkpoints for 12033 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-02:51:42
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-12033
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-02:51:54
# INFO:tensorflow:Saving dict for global step 12033: acc = 0.8305171, global_step = 12033, loss = 0.4398485
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 12033: ../model/esim/model.ckpt-12033
# INFO:tensorflow:global_step/sec: 3.56513
# INFO:tensorflow:loss = 0.5682852, step = 12100 (28.051 sec)
# INFO:tensorflow:lr = 0.00033822889 (28.051 sec)
# INFO:tensorflow:global_step/sec: 6.85036
# INFO:tensorflow:loss = 0.6576648, step = 12200 (14.597 sec)
# INFO:tensorflow:lr = 0.00033776034 (14.599 sec)
# INFO:tensorflow:global_step/sec: 7.08772
# INFO:tensorflow:loss = 0.42098752, step = 12300 (14.106 sec)
# INFO:tensorflow:lr = 0.0003372924 (14.106 sec)
# INFO:tensorflow:global_step/sec: 7.10208
# INFO:tensorflow:loss = 0.5661807, step = 12400 (14.080 sec)
# INFO:tensorflow:lr = 0.00033682518 (14.080 sec)
# INFO:tensorflow:global_step/sec: 6.99211
# INFO:tensorflow:loss = 0.58017296, step = 12500 (14.302 sec)
# INFO:tensorflow:lr = 0.00033635853 (14.304 sec)
# INFO:tensorflow:global_step/sec: 7.13917
# INFO:tensorflow:loss = 0.6505108, step = 12600 (14.006 sec)
# INFO:tensorflow:lr = 0.00033589258 (14.003 sec)
# INFO:tensorflow:global_step/sec: 7.28392
# INFO:tensorflow:loss = 0.60204816, step = 12700 (13.729 sec)
# INFO:tensorflow:lr = 0.00033542726 (13.729 sec)
# INFO:tensorflow:global_step/sec: 6.91382
# INFO:tensorflow:loss = 0.6169034, step = 12800 (14.465 sec)
# INFO:tensorflow:lr = 0.0003349626 (14.465 sec)
# INFO:tensorflow:global_step/sec: 6.88414
# INFO:tensorflow:loss = 0.40826982, step = 12900 (14.525 sec)
# INFO:tensorflow:lr = 0.00033449856 (14.525 sec)
# INFO:tensorflow:global_step/sec: 6.99686
# INFO:tensorflow:loss = 0.63299036, step = 13000 (14.292 sec)
# INFO:tensorflow:lr = 0.00033403514 (14.296 sec)
# INFO:tensorflow:global_step/sec: 7.11406
# INFO:tensorflow:loss = 0.53709424, step = 13100 (14.057 sec)
# INFO:tensorflow:lr = 0.0003335724 (14.054 sec)
# INFO:tensorflow:global_step/sec: 7.08722
# INFO:tensorflow:loss = 0.5428653, step = 13200 (14.112 sec)
# INFO:tensorflow:lr = 0.0003331103 (14.112 sec)
# INFO:tensorflow:global_step/sec: 7.0611
# INFO:tensorflow:loss = 0.7549263, step = 13300 (14.161 sec)
# INFO:tensorflow:lr = 0.0003326488 (14.161 sec)
# INFO:tensorflow:global_step/sec: 7.16426
# INFO:tensorflow:loss = 0.44431219, step = 13400 (13.957 sec)
# INFO:tensorflow:lr = 0.00033218798 (13.961 sec)
# INFO:tensorflow:global_step/sec: 7.20867
# INFO:tensorflow:loss = 0.7055365, step = 13500 (13.870 sec)
# INFO:tensorflow:lr = 0.00033172782 (13.868 sec)
# INFO:tensorflow:global_step/sec: 7.13305
# INFO:tensorflow:loss = 0.4860137, step = 13600 (14.023 sec)
# INFO:tensorflow:lr = 0.00033126827 (14.021 sec)
# INFO:tensorflow:global_step/sec: 7.0011
# INFO:tensorflow:loss = 0.47432005, step = 13700 (14.277 sec)
# INFO:tensorflow:lr = 0.00033080936 (14.279 sec)
# INFO:tensorflow:Saving checkpoints for 13752 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-02:55:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-13752
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-02:56:11
# INFO:tensorflow:Saving dict for global step 13752: acc = 0.833978, global_step = 13752, loss = 0.42392296
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13752: ../model/esim/model.ckpt-13752
# INFO:tensorflow:global_step/sec: 3.60265
# INFO:tensorflow:loss = 0.66332215, step = 13800 (27.763 sec)
# INFO:tensorflow:lr = 0.00033035106 (27.762 sec)
# INFO:tensorflow:global_step/sec: 7.09768
# INFO:tensorflow:loss = 0.29036576, step = 13900 (14.092 sec)
# INFO:tensorflow:lr = 0.0003298934 (14.092 sec)
# INFO:tensorflow:global_step/sec: 7.01528
# INFO:tensorflow:loss = 0.42414778, step = 14000 (14.247 sec)
# INFO:tensorflow:lr = 0.00032943639 (14.248 sec)
# INFO:tensorflow:global_step/sec: 6.94696
# INFO:tensorflow:loss = 0.6846696, step = 14100 (14.394 sec)
# INFO:tensorflow:lr = 0.00032898 (14.392 sec)
# INFO:tensorflow:global_step/sec: 6.96431
# INFO:tensorflow:loss = 0.53348666, step = 14200 (14.362 sec)
# INFO:tensorflow:lr = 0.00032852427 (14.364 sec)
# INFO:tensorflow:global_step/sec: 7.15184
# INFO:tensorflow:loss = 0.7068944, step = 14300 (13.983 sec)
# INFO:tensorflow:lr = 0.00032806915 (13.983 sec)
# INFO:tensorflow:global_step/sec: 6.91996
# INFO:tensorflow:loss = 0.387451, step = 14400 (14.451 sec)
# INFO:tensorflow:lr = 0.00032761466 (14.449 sec)
# INFO:tensorflow:global_step/sec: 7.1395
# INFO:tensorflow:loss = 0.4529258, step = 14500 (14.007 sec)
# INFO:tensorflow:lr = 0.00032716081 (14.009 sec)
# INFO:tensorflow:global_step/sec: 7.12916
# INFO:tensorflow:loss = 0.4075611, step = 14600 (14.030 sec)
# INFO:tensorflow:lr = 0.00032670758 (14.030 sec)
# INFO:tensorflow:global_step/sec: 6.97309
# INFO:tensorflow:loss = 0.42727715, step = 14700 (14.343 sec)
# INFO:tensorflow:lr = 0.000326255 (14.341 sec)
# INFO:tensorflow:global_step/sec: 7.10306
# INFO:tensorflow:loss = 0.83525383, step = 14800 (14.076 sec)
# INFO:tensorflow:lr = 0.00032580298 (14.076 sec)
# INFO:tensorflow:global_step/sec: 7.11251
# INFO:tensorflow:loss = 0.6216323, step = 14900 (14.058 sec)
# INFO:tensorflow:lr = 0.00032535166 (14.062 sec)
# INFO:tensorflow:global_step/sec: 7.21791
# INFO:tensorflow:loss = 0.8140732, step = 15000 (13.852 sec)
# INFO:tensorflow:lr = 0.00032490096 (13.848 sec)
# INFO:tensorflow:global_step/sec: 6.96546
# INFO:tensorflow:loss = 0.47216994, step = 15100 (14.361 sec)
# INFO:tensorflow:lr = 0.00032445087 (14.361 sec)
# INFO:tensorflow:global_step/sec: 7.18939
# INFO:tensorflow:loss = 0.5511131, step = 15200 (13.909 sec)
# INFO:tensorflow:lr = 0.0003240014 (13.909 sec)
# INFO:tensorflow:global_step/sec: 6.75799
# INFO:tensorflow:loss = 0.56159794, step = 15300 (14.792 sec)
# INFO:tensorflow:lr = 0.0003235525 (14.802 sec)
# INFO:tensorflow:global_step/sec: 7.35471
# INFO:tensorflow:loss = 0.467021, step = 15400 (13.598 sec)
# INFO:tensorflow:lr = 0.0003231043 (13.589 sec)
# INFO:tensorflow:Saving checkpoints for 15471 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-03:00:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-15471
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-03:00:28
# INFO:tensorflow:Saving dict for global step 15471: acc = 0.8430375, global_step = 15471, loss = 0.40850356
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 15471: ../model/esim/model.ckpt-15471
# INFO:tensorflow:global_step/sec: 3.60978
# INFO:tensorflow:loss = 0.65668464, step = 15500 (27.705 sec)
# INFO:tensorflow:lr = 0.0003226567 (27.708 sec)
# INFO:tensorflow:global_step/sec: 6.96575
# INFO:tensorflow:loss = 0.25026125, step = 15600 (14.360 sec)
# INFO:tensorflow:lr = 0.0003222097 (14.355 sec)
# INFO:tensorflow:global_step/sec: 6.95662
# INFO:tensorflow:loss = 0.5548582, step = 15700 (14.368 sec)
# INFO:tensorflow:lr = 0.00032176333 (14.372 sec)
# INFO:tensorflow:global_step/sec: 7.07132
# INFO:tensorflow:loss = 0.5141926, step = 15800 (14.146 sec)
# INFO:tensorflow:lr = 0.00032131758 (14.146 sec)
# INFO:tensorflow:global_step/sec: 7.13286
# INFO:tensorflow:loss = 0.38066667, step = 15900 (14.014 sec)
# INFO:tensorflow:lr = 0.00032087247 (14.011 sec)
# INFO:tensorflow:global_step/sec: 7.0338
# INFO:tensorflow:loss = 0.51845807, step = 16000 (14.222 sec)
# INFO:tensorflow:lr = 0.00032042796 (14.223 sec)
# INFO:tensorflow:global_step/sec: 7.11329
# INFO:tensorflow:loss = 0.45372117, step = 16100 (14.053 sec)
# INFO:tensorflow:lr = 0.00031998404 (14.053 sec)
# INFO:tensorflow:global_step/sec: 7.06613
# INFO:tensorflow:loss = 0.46311235, step = 16200 (14.157 sec)
# INFO:tensorflow:lr = 0.00031954073 (14.158 sec)
# INFO:tensorflow:global_step/sec: 7.09715
# INFO:tensorflow:loss = 0.60264635, step = 16300 (14.091 sec)
# INFO:tensorflow:lr = 0.0003190981 (14.091 sec)
# INFO:tensorflow:global_step/sec: 7.1112
# INFO:tensorflow:loss = 0.39698875, step = 16400 (14.057 sec)
# INFO:tensorflow:lr = 0.00031865604 (14.058 sec)
# INFO:tensorflow:global_step/sec: 7.15953
# INFO:tensorflow:loss = 0.3566866, step = 16500 (13.968 sec)
# INFO:tensorflow:lr = 0.0003182146 (13.971 sec)
# INFO:tensorflow:global_step/sec: 7.00422
# INFO:tensorflow:loss = 0.6134451, step = 16600 (14.275 sec)
# INFO:tensorflow:lr = 0.00031777375 (14.274 sec)
# INFO:tensorflow:global_step/sec: 7.15016
# INFO:tensorflow:loss = 0.30238095, step = 16700 (13.986 sec)
# INFO:tensorflow:lr = 0.00031733353 (13.988 sec)
# INFO:tensorflow:global_step/sec: 6.97259
# INFO:tensorflow:loss = 0.56854284, step = 16800 (14.342 sec)
# INFO:tensorflow:lr = 0.00031689391 (14.340 sec)
# INFO:tensorflow:global_step/sec: 7.15778
# INFO:tensorflow:loss = 0.76229453, step = 16900 (13.971 sec)
# INFO:tensorflow:lr = 0.0003164549 (13.973 sec)
# INFO:tensorflow:global_step/sec: 7.05531
# INFO:tensorflow:loss = 0.40027022, step = 17000 (14.180 sec)
# INFO:tensorflow:lr = 0.00031601652 (14.175 sec)
# INFO:tensorflow:global_step/sec: 6.94174
# INFO:tensorflow:loss = 0.716519, step = 17100 (14.399 sec)
# INFO:tensorflow:lr = 0.00031557874 (14.399 sec)
# Reading ../data/train.txt
# INFO:tensorflow:Saving checkpoints for 17190 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-03:06:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-17190
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-03:06:25
# INFO:tensorflow:Saving dict for global step 17190: acc = 0.8399837, global_step = 17190, loss = 0.41126752
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 17190: ../model/esim/model.ckpt-17190
# INFO:tensorflow:global_step/sec: 0.782751
# INFO:tensorflow:loss = 0.5561242, step = 17200 (127.759 sec)
# INFO:tensorflow:lr = 0.00031514151 (127.760 sec)
# INFO:tensorflow:global_step/sec: 7.11789
# INFO:tensorflow:loss = 0.5553887, step = 17300 (14.047 sec)
# INFO:tensorflow:lr = 0.00031470496 (14.050 sec)
# INFO:tensorflow:global_step/sec: 7.06144
# INFO:tensorflow:loss = 0.5050351, step = 17400 (14.158 sec)
# INFO:tensorflow:lr = 0.00031426898 (14.164 sec)
# INFO:tensorflow:global_step/sec: 6.92512
# INFO:tensorflow:loss = 0.6824051, step = 17500 (14.440 sec)
# INFO:tensorflow:lr = 0.00031383365 (14.431 sec)
# INFO:tensorflow:global_step/sec: 7.13544
# INFO:tensorflow:loss = 0.444389, step = 17600 (14.020 sec)
# INFO:tensorflow:lr = 0.00031339884 (14.023 sec)
# INFO:tensorflow:global_step/sec: 7.05009
# INFO:tensorflow:loss = 0.4917812, step = 17700 (14.179 sec)
# INFO:tensorflow:lr = 0.0003129647 (14.180 sec)
# INFO:tensorflow:global_step/sec: 7.15185
# INFO:tensorflow:loss = 0.29463536, step = 17800 (13.993 sec)
# INFO:tensorflow:lr = 0.00031253113 (13.993 sec)
# INFO:tensorflow:global_step/sec: 7.13212
# INFO:tensorflow:loss = 0.36017168, step = 17900 (14.013 sec)
# INFO:tensorflow:lr = 0.0003120982 (14.014 sec)
# INFO:tensorflow:global_step/sec: 6.91869
# INFO:tensorflow:loss = 0.43245536, step = 18000 (14.458 sec)
# INFO:tensorflow:lr = 0.00031166585 (14.452 sec)
# INFO:tensorflow:global_step/sec: 7.06644
# INFO:tensorflow:loss = 0.30300602, step = 18100 (14.146 sec)
# INFO:tensorflow:lr = 0.00031123406 (14.153 sec)
# INFO:tensorflow:global_step/sec: 7.16323
# INFO:tensorflow:loss = 0.3382422, step = 18200 (13.964 sec)
# INFO:tensorflow:lr = 0.0003108029 (13.959 sec)
# INFO:tensorflow:global_step/sec: 7.02131
# INFO:tensorflow:loss = 0.37016752, step = 18300 (14.242 sec)
# INFO:tensorflow:lr = 0.00031037236 (14.241 sec)
# INFO:tensorflow:global_step/sec: 7.04866
# INFO:tensorflow:loss = 0.77205825, step = 18400 (14.189 sec)
# INFO:tensorflow:lr = 0.00030994235 (14.189 sec)
# INFO:tensorflow:global_step/sec: 6.94268
# INFO:tensorflow:loss = 0.6819425, step = 18500 (14.404 sec)
# INFO:tensorflow:lr = 0.00030951298 (14.403 sec)
# INFO:tensorflow:global_step/sec: 7.1969
# INFO:tensorflow:loss = 0.31443292, step = 18600 (13.896 sec)
# INFO:tensorflow:lr = 0.0003090842 (13.897 sec)
# INFO:tensorflow:global_step/sec: 7.04315
# INFO:tensorflow:loss = 0.60632086, step = 18700 (14.197 sec)
# INFO:tensorflow:lr = 0.00030865602 (14.196 sec)
# INFO:tensorflow:global_step/sec: 7.12885
# INFO:tensorflow:loss = 0.27554655, step = 18800 (14.021 sec)
# INFO:tensorflow:lr = 0.00030822842 (14.026 sec)
# INFO:tensorflow:global_step/sec: 6.89807
# INFO:tensorflow:loss = 0.40693086, step = 18900 (14.504 sec)
# INFO:tensorflow:lr = 0.00030780144 (14.500 sec)
# INFO:tensorflow:Saving checkpoints for 18909 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-03:10:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-18909
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-03:10:42
# INFO:tensorflow:Saving dict for global step 18909: acc = 0.8485342, global_step = 18909, loss = 0.3936698
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 18909: ../model/esim/model.ckpt-18909
# INFO:tensorflow:global_step/sec: 3.59995
# INFO:tensorflow:loss = 0.42151392, step = 19000 (27.771 sec)
# INFO:tensorflow:lr = 0.000307375 (27.771 sec)
# INFO:tensorflow:global_step/sec: 7.02033
# INFO:tensorflow:loss = 0.49041525, step = 19100 (14.244 sec)
# INFO:tensorflow:lr = 0.0003069492 (14.244 sec)
# INFO:tensorflow:global_step/sec: 6.95066
# INFO:tensorflow:loss = 0.45962986, step = 19200 (14.388 sec)
# INFO:tensorflow:lr = 0.000306524 (14.389 sec)
# INFO:tensorflow:global_step/sec: 7.16082
# INFO:tensorflow:loss = 0.67427075, step = 19300 (13.964 sec)
# INFO:tensorflow:lr = 0.00030609936 (13.963 sec)
# INFO:tensorflow:global_step/sec: 7.16566
# INFO:tensorflow:loss = 0.5478408, step = 19400 (13.955 sec)
# INFO:tensorflow:lr = 0.00030567532 (13.957 sec)
# INFO:tensorflow:global_step/sec: 7.09225
# INFO:tensorflow:loss = 0.38368326, step = 19500 (14.106 sec)
# INFO:tensorflow:lr = 0.00030525183 (14.105 sec)
# INFO:tensorflow:global_step/sec: 7.07667
# INFO:tensorflow:loss = 0.45643842, step = 19600 (14.125 sec)
# INFO:tensorflow:lr = 0.00030482895 (14.128 sec)
# INFO:tensorflow:global_step/sec: 7.19544
# INFO:tensorflow:loss = 0.48058593, step = 19700 (13.898 sec)
# INFO:tensorflow:lr = 0.00030440665 (13.904 sec)
# INFO:tensorflow:global_step/sec: 6.8853
# INFO:tensorflow:loss = 0.44018468, step = 19800 (14.524 sec)
# INFO:tensorflow:lr = 0.00030398497 (14.517 sec)
# INFO:tensorflow:global_step/sec: 7.15815
# INFO:tensorflow:loss = 0.40805787, step = 19900 (13.970 sec)
# INFO:tensorflow:lr = 0.00030356384 (13.971 sec)
# INFO:tensorflow:global_step/sec: 7.18379
# INFO:tensorflow:loss = 0.42780054, step = 20000 (13.927 sec)
# INFO:tensorflow:lr = 0.00030314332 (13.925 sec)
# INFO:tensorflow:global_step/sec: 7.25557
# INFO:tensorflow:loss = 0.29105073, step = 20100 (13.779 sec)
# INFO:tensorflow:lr = 0.00030272332 (13.780 sec)
# INFO:tensorflow:global_step/sec: 7.08739
# INFO:tensorflow:loss = 0.3686663, step = 20200 (14.108 sec)
# INFO:tensorflow:lr = 0.00030230396 (14.107 sec)
# INFO:tensorflow:global_step/sec: 7.11766
# INFO:tensorflow:loss = 0.27755415, step = 20300 (14.046 sec)
# INFO:tensorflow:lr = 0.0003018852 (14.051 sec)
# INFO:tensorflow:global_step/sec: 6.98532
# INFO:tensorflow:loss = 0.2950467, step = 20400 (14.316 sec)
# INFO:tensorflow:lr = 0.00030146696 (14.314 sec)
# INFO:tensorflow:global_step/sec: 7.05579
# INFO:tensorflow:loss = 0.26738262, step = 20500 (14.173 sec)
# INFO:tensorflow:lr = 0.00030104935 (14.172 sec)
# INFO:tensorflow:global_step/sec: 6.99428
# INFO:tensorflow:loss = 0.18626265, step = 20600 (14.305 sec)
# INFO:tensorflow:lr = 0.00030063227 (14.304 sec)
# INFO:tensorflow:Saving checkpoints for 20628 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-03:14:47
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-20628
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-03:14:59
# INFO:tensorflow:Saving dict for global step 20628: acc = 0.8469055, global_step = 20628, loss = 0.3887273
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20628: ../model/esim/model.ckpt-20628
# INFO:tensorflow:global_step/sec: 3.58095
# INFO:tensorflow:loss = 0.425079, step = 20700 (27.922 sec)
# INFO:tensorflow:lr = 0.00030021582 (27.928 sec)
# INFO:tensorflow:global_step/sec: 7.11657
# INFO:tensorflow:loss = 0.7595109, step = 20800 (14.048 sec)
# INFO:tensorflow:lr = 0.00029979993 (14.047 sec)
# INFO:tensorflow:global_step/sec: 7.01068
# INFO:tensorflow:loss = 0.4887423, step = 20900 (14.270 sec)
# INFO:tensorflow:lr = 0.00029938458 (14.267 sec)
# INFO:tensorflow:global_step/sec: 7.06457
# INFO:tensorflow:loss = 0.3292652, step = 21000 (14.153 sec)
# INFO:tensorflow:lr = 0.00029896983 (14.151 sec)
# INFO:tensorflow:global_step/sec: 7.10727
# INFO:tensorflow:loss = 0.52436674, step = 21100 (14.071 sec)
# INFO:tensorflow:lr = 0.00029855565 (14.071 sec)
# INFO:tensorflow:global_step/sec: 6.98087
# INFO:tensorflow:loss = 0.37359214, step = 21200 (14.326 sec)
# INFO:tensorflow:lr = 0.00029814205 (14.329 sec)
# INFO:tensorflow:global_step/sec: 7.08013
# INFO:tensorflow:loss = 0.36335844, step = 21300 (14.118 sec)
# INFO:tensorflow:lr = 0.00029772904 (14.121 sec)
# INFO:tensorflow:global_step/sec: 7.25578
# INFO:tensorflow:loss = 0.32582512, step = 21400 (13.783 sec)
# INFO:tensorflow:lr = 0.00029731658 (13.781 sec)
# INFO:tensorflow:global_step/sec: 7.13344
# INFO:tensorflow:loss = 0.31484795, step = 21500 (14.018 sec)
# INFO:tensorflow:lr = 0.0002969047 (14.016 sec)
# INFO:tensorflow:global_step/sec: 7.18666
# INFO:tensorflow:loss = 0.37080726, step = 21600 (13.915 sec)
# INFO:tensorflow:lr = 0.0002964934 (13.919 sec)
# INFO:tensorflow:global_step/sec: 7.05741
# INFO:tensorflow:loss = 0.2567707, step = 21700 (14.174 sec)
# INFO:tensorflow:lr = 0.00029608267 (14.168 sec)
# INFO:tensorflow:global_step/sec: 7.22159
# INFO:tensorflow:loss = 0.5000431, step = 21800 (13.843 sec)
# INFO:tensorflow:lr = 0.00029567248 (13.842 sec)
# INFO:tensorflow:global_step/sec: 7.32259
# INFO:tensorflow:loss = 0.4511811, step = 21900 (13.658 sec)
# INFO:tensorflow:lr = 0.00029526284 (13.659 sec)
# INFO:tensorflow:global_step/sec: 7.2077
# INFO:tensorflow:loss = 0.3437813, step = 22000 (13.876 sec)
# INFO:tensorflow:lr = 0.00029485385 (13.874 sec)
# INFO:tensorflow:global_step/sec: 7.18492
# INFO:tensorflow:loss = 0.70659214, step = 22100 (13.919 sec)
# INFO:tensorflow:lr = 0.00029444537 (13.920 sec)
# INFO:tensorflow:global_step/sec: 7.39506
# INFO:tensorflow:loss = 0.50142074, step = 22200 (13.524 sec)
# INFO:tensorflow:lr = 0.00029403748 (13.524 sec)
# INFO:tensorflow:global_step/sec: 7.07527
# INFO:tensorflow:loss = 0.3487975, step = 22300 (14.128 sec)
# INFO:tensorflow:lr = 0.00029363012 (14.128 sec)
# INFO:tensorflow:Saving checkpoints for 22347 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-03:19:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-22347
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-03:19:13
# INFO:tensorflow:Saving dict for global step 22347: acc = 0.84771985, global_step = 22347, loss = 0.39029944
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 22347: ../model/esim/model.ckpt-22347
# INFO:tensorflow:global_step/sec: 3.61057
# INFO:tensorflow:loss = 0.41963238, step = 22400 (27.696 sec)
# INFO:tensorflow:lr = 0.00029322336 (27.702 sec)
# INFO:tensorflow:global_step/sec: 7.25927
# INFO:tensorflow:loss = 0.3573841, step = 22500 (13.778 sec)
# INFO:tensorflow:lr = 0.00029281713 (13.772 sec)
# INFO:tensorflow:global_step/sec: 7.03027
# INFO:tensorflow:loss = 0.36315805, step = 22600 (14.221 sec)
# INFO:tensorflow:lr = 0.00029241148 (14.223 sec)
# INFO:tensorflow:global_step/sec: 6.95374
# INFO:tensorflow:loss = 0.69931066, step = 22700 (14.381 sec)
# INFO:tensorflow:lr = 0.00029200636 (14.385 sec)
# INFO:tensorflow:global_step/sec: 7.16868
# INFO:tensorflow:loss = 0.6306081, step = 22800 (13.949 sec)
# INFO:tensorflow:lr = 0.00029160187 (13.951 sec)
# INFO:tensorflow:global_step/sec: 6.94117
# INFO:tensorflow:loss = 0.40698105, step = 22900 (14.411 sec)
# INFO:tensorflow:lr = 0.00029119788 (14.404 sec)
# INFO:tensorflow:global_step/sec: 6.98187
# INFO:tensorflow:loss = 0.3287804, step = 23000 (14.323 sec)
# INFO:tensorflow:lr = 0.0002907945 (14.325 sec)
# INFO:tensorflow:global_step/sec: 7.02451
# INFO:tensorflow:loss = 0.5186238, step = 23100 (14.233 sec)
# INFO:tensorflow:lr = 0.00029039165 (14.233 sec)
# INFO:tensorflow:global_step/sec: 7.32701
# INFO:tensorflow:loss = 0.4969671, step = 23200 (13.650 sec)
# INFO:tensorflow:lr = 0.00028998934 (13.649 sec)
# INFO:tensorflow:global_step/sec: 7.05483
# INFO:tensorflow:loss = 0.36265683, step = 23300 (14.178 sec)
# INFO:tensorflow:lr = 0.00028958762 (14.176 sec)
# INFO:tensorflow:global_step/sec: 7.10621
# INFO:tensorflow:loss = 0.33382925, step = 23400 (14.073 sec)
# INFO:tensorflow:lr = 0.00028918646 (14.072 sec)
# INFO:tensorflow:global_step/sec: 7.17913
# INFO:tensorflow:loss = 0.4722674, step = 23500 (13.923 sec)
# INFO:tensorflow:lr = 0.00028878584 (13.929 sec)
# INFO:tensorflow:global_step/sec: 7.04312
# INFO:tensorflow:loss = 0.35689732, step = 23600 (14.198 sec)
# INFO:tensorflow:lr = 0.00028838575 (14.192 sec)
# INFO:tensorflow:global_step/sec: 7.03533
# INFO:tensorflow:loss = 0.3522628, step = 23700 (14.219 sec)
# INFO:tensorflow:lr = 0.00028798627 (14.219 sec)
# INFO:tensorflow:global_step/sec: 7.197
# INFO:tensorflow:loss = 0.5704387, step = 23800 (13.890 sec)
# INFO:tensorflow:lr = 0.0002875873 (13.898 sec)
# INFO:tensorflow:global_step/sec: 7.01552
# INFO:tensorflow:loss = 0.25284714, step = 23900 (14.259 sec)
# INFO:tensorflow:lr = 0.00028718892 (14.254 sec)
# INFO:tensorflow:global_step/sec: 7.11091
# INFO:tensorflow:loss = 0.57871217, step = 24000 (14.061 sec)
# INFO:tensorflow:lr = 0.00028679107 (14.063 sec)
# INFO:tensorflow:Saving checkpoints for 24066 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-03:23:18
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-24066
# ...
# INFO:tensorflow:global_step/sec: 6.92022
# INFO:tensorflow:loss = 0.30443335, step = 80100 (14.449 sec)
# INFO:tensorflow:lr = 0.00013176799 (14.448 sec)
# INFO:tensorflow:global_step/sec: 7.04913
# INFO:tensorflow:loss = 0.4746247, step = 80200 (14.186 sec)
# INFO:tensorflow:lr = 0.00013158545 (14.193 sec)
# INFO:tensorflow:global_step/sec: 6.97721
# INFO:tensorflow:loss = 0.32845706, step = 80300 (14.333 sec)
# INFO:tensorflow:lr = 0.00013140315 (14.325 sec)
# INFO:tensorflow:global_step/sec: 6.98807
# INFO:tensorflow:loss = 0.35138175, step = 80400 (14.310 sec)
# INFO:tensorflow:lr = 0.00013122112 (14.317 sec)
# INFO:tensorflow:global_step/sec: 6.80933
# INFO:tensorflow:loss = 0.32225394, step = 80500 (14.690 sec)
# INFO:tensorflow:lr = 0.00013103933 (14.686 sec)
# INFO:tensorflow:global_step/sec: 7.20092
# INFO:tensorflow:loss = 0.5237817, step = 80600 (13.886 sec)
# INFO:tensorflow:lr = 0.00013085779 (13.886 sec)
# INFO:tensorflow:global_step/sec: 6.99181
# INFO:tensorflow:loss = 0.18878773, step = 80700 (14.304 sec)
# INFO:tensorflow:lr = 0.00013067653 (14.303 sec)
# INFO:tensorflow:Saving checkpoints for 80793 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-05:49:46
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-80793
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-05:49:58
# INFO:tensorflow:Saving dict for global step 80793: acc = 0.87337136, global_step = 80793, loss = 0.34543252
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 80793: ../model/esim/model.ckpt-80793
# INFO:tensorflow:global_step/sec: 3.5981
# INFO:tensorflow:loss = 0.37147808, step = 80800 (27.792 sec)
# INFO:tensorflow:lr = 0.0001304955 (27.791 sec)
# INFO:tensorflow:global_step/sec: 7.1727
# INFO:tensorflow:loss = 0.34671664, step = 80900 (13.944 sec)
# INFO:tensorflow:lr = 0.00013031473 (13.944 sec)
# INFO:tensorflow:global_step/sec: 7.06389
# INFO:tensorflow:loss = 0.25658214, step = 81000 (14.153 sec)
# INFO:tensorflow:lr = 0.00013013417 (14.154 sec)
# INFO:tensorflow:global_step/sec: 6.94407
# INFO:tensorflow:loss = 0.28835577, step = 81100 (14.398 sec)
# INFO:tensorflow:lr = 0.0001299539 (14.398 sec)
# INFO:tensorflow:global_step/sec: 7.19745
# INFO:tensorflow:loss = 0.29907852, step = 81200 (13.892 sec)
# INFO:tensorflow:lr = 0.00012977386 (13.901 sec)
# INFO:tensorflow:global_step/sec: 7.10909
# INFO:tensorflow:loss = 0.18722421, step = 81300 (14.069 sec)
# INFO:tensorflow:lr = 0.0001295941 (14.060 sec)
# INFO:tensorflow:global_step/sec: 7.04671
# INFO:tensorflow:loss = 0.4358203, step = 81400 (14.189 sec)
# INFO:tensorflow:lr = 0.00012941458 (14.193 sec)
# INFO:tensorflow:global_step/sec: 7.05964
# INFO:tensorflow:loss = 0.42310005, step = 81500 (14.174 sec)
# INFO:tensorflow:lr = 0.00012923528 (14.168 sec)
# INFO:tensorflow:global_step/sec: 7.19714
# INFO:tensorflow:loss = 0.28422222, step = 81600 (13.894 sec)
# INFO:tensorflow:lr = 0.00012905625 (13.896 sec)
# INFO:tensorflow:global_step/sec: 7.03876
# INFO:tensorflow:loss = 0.294939, step = 81700 (14.203 sec)
# INFO:tensorflow:lr = 0.00012887745 (14.205 sec)
# INFO:tensorflow:global_step/sec: 6.93363
# INFO:tensorflow:loss = 0.2957992, step = 81800 (14.418 sec)
# INFO:tensorflow:lr = 0.00012869891 (14.419 sec)
# INFO:tensorflow:global_step/sec: 6.95803
# INFO:tensorflow:loss = 0.31571662, step = 81900 (14.378 sec)
# INFO:tensorflow:lr = 0.00012852064 (14.374 sec)
# INFO:tensorflow:global_step/sec: 7.0255
# INFO:tensorflow:loss = 0.25037482, step = 82000 (14.233 sec)
# INFO:tensorflow:lr = 0.00012834258 (14.235 sec)
# INFO:tensorflow:global_step/sec: 7.00953
# INFO:tensorflow:loss = 0.1876144, step = 82100 (14.267 sec)
# INFO:tensorflow:lr = 0.00012816479 (14.263 sec)
# INFO:tensorflow:global_step/sec: 6.95795
# INFO:tensorflow:loss = 0.28278315, step = 82200 (14.366 sec)
# INFO:tensorflow:lr = 0.00012798725 (14.371 sec)
# INFO:tensorflow:global_step/sec: 7.1344
# INFO:tensorflow:loss = 0.43674895, step = 82300 (14.022 sec)
# INFO:tensorflow:lr = 0.00012780995 (14.019 sec)
# INFO:tensorflow:global_step/sec: 6.78729
# INFO:tensorflow:loss = 0.5366941, step = 82400 (14.737 sec)
# INFO:tensorflow:lr = 0.00012763287 (14.735 sec)
# INFO:tensorflow:global_step/sec: 7.24567
# INFO:tensorflow:loss = 0.29678953, step = 82500 (13.794 sec)
# INFO:tensorflow:lr = 0.00012745605 (13.796 sec)
# INFO:tensorflow:Saving checkpoints for 82512 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-05:54:03
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-82512
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-05:54:15
# INFO:tensorflow:Saving dict for global step 82512: acc = 0.8736767, global_step = 82512, loss = 0.34578994
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 82512: ../model/esim/model.ckpt-82512
# INFO:tensorflow:global_step/sec: 3.58237
# INFO:tensorflow:loss = 0.11997895, step = 82600 (27.912 sec)
# INFO:tensorflow:lr = 0.00012727949 (27.911 sec)
# INFO:tensorflow:global_step/sec: 7.12873
# INFO:tensorflow:loss = 0.2960469, step = 82700 (14.036 sec)
# INFO:tensorflow:lr = 0.00012710317 (14.035 sec)
# INFO:tensorflow:global_step/sec: 7.23188
# INFO:tensorflow:loss = 0.2696757, step = 82800 (13.823 sec)
# INFO:tensorflow:lr = 0.00012692709 (13.823 sec)
# INFO:tensorflow:global_step/sec: 7.16053
# INFO:tensorflow:loss = 0.25412282, step = 82900 (13.966 sec)
# INFO:tensorflow:lr = 0.00012675126 (13.967 sec)
# INFO:tensorflow:global_step/sec: 7.01996
# INFO:tensorflow:loss = 0.5127348, step = 83000 (14.248 sec)
# INFO:tensorflow:lr = 0.00012657567 (14.247 sec)
# INFO:tensorflow:global_step/sec: 7.07654
# INFO:tensorflow:loss = 0.42874065, step = 83100 (14.131 sec)
# INFO:tensorflow:lr = 0.00012640031 (14.133 sec)
# INFO:tensorflow:global_step/sec: 7.0995
# INFO:tensorflow:loss = 0.3746469, step = 83200 (14.079 sec)
# INFO:tensorflow:lr = 0.0001262252 (14.077 sec)
# INFO:tensorflow:global_step/sec: 7.12001
# INFO:tensorflow:loss = 0.38830426, step = 83300 (14.048 sec)
# INFO:tensorflow:lr = 0.00012605032 (14.053 sec)
# INFO:tensorflow:global_step/sec: 7.15357
# INFO:tensorflow:loss = 0.41505522, step = 83400 (13.975 sec)
# INFO:tensorflow:lr = 0.00012587573 (13.970 sec)
# INFO:tensorflow:global_step/sec: 7.09091
# INFO:tensorflow:loss = 0.39789444, step = 83500 (14.109 sec)
# INFO:tensorflow:lr = 0.00012570134 (14.109 sec)
# INFO:tensorflow:global_step/sec: 6.93488
# INFO:tensorflow:loss = 0.21370497, step = 83600 (14.414 sec)
# INFO:tensorflow:lr = 0.00012552719 (14.414 sec)
# INFO:tensorflow:global_step/sec: 7.0369
# INFO:tensorflow:loss = 0.1312942, step = 83700 (14.214 sec)
# INFO:tensorflow:lr = 0.00012535331 (14.216 sec)
# INFO:tensorflow:global_step/sec: 6.95381
# INFO:tensorflow:loss = 0.18894655, step = 83800 (14.384 sec)
# INFO:tensorflow:lr = 0.00012517963 (14.387 sec)
# INFO:tensorflow:global_step/sec: 7.05883
# INFO:tensorflow:loss = 0.1922647, step = 83900 (14.161 sec)
# INFO:tensorflow:lr = 0.00012500622 (14.155 sec)
# INFO:tensorflow:global_step/sec: 7.14733
# INFO:tensorflow:loss = 0.38676196, step = 84000 (13.998 sec)
# INFO:tensorflow:lr = 0.00012483304 (13.998 sec)
# INFO:tensorflow:global_step/sec: 7.14738
# INFO:tensorflow:loss = 0.100727975, step = 84100 (13.985 sec)
# INFO:tensorflow:lr = 0.00012466012 (13.989 sec)
# INFO:tensorflow:global_step/sec: 6.97441
# INFO:tensorflow:loss = 0.19382139, step = 84200 (14.340 sec)
# INFO:tensorflow:lr = 0.00012448741 (14.345 sec)
# INFO:tensorflow:Saving checkpoints for 84231 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-05:58:20
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-84231
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-05:58:31
# INFO:tensorflow:Saving dict for global step 84231: acc = 0.8705212, global_step = 84231, loss = 0.3439391
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 84231: ../model/esim/model.ckpt-84231
# INFO:tensorflow:global_step/sec: 3.57588
# INFO:tensorflow:loss = 0.18110788, step = 84300 (27.967 sec)
# INFO:tensorflow:lr = 0.00012431497 (27.961 sec)
# INFO:tensorflow:global_step/sec: 7.21947
# INFO:tensorflow:loss = 0.32089812, step = 84400 (13.848 sec)
# INFO:tensorflow:lr = 0.00012414277 (13.849 sec)
# INFO:tensorflow:global_step/sec: 7.23674
# INFO:tensorflow:loss = 0.4216858, step = 84500 (13.817 sec)
# INFO:tensorflow:lr = 0.00012397078 (13.821 sec)
# INFO:tensorflow:global_step/sec: 7.01476
# INFO:tensorflow:loss = 0.32444614, step = 84600 (14.263 sec)
# INFO:tensorflow:lr = 0.00012379904 (14.257 sec)
# INFO:tensorflow:global_step/sec: 7.08229
# INFO:tensorflow:loss = 0.2662077, step = 84700 (14.120 sec)
# INFO:tensorflow:lr = 0.00012362751 (14.121 sec)
# INFO:tensorflow:global_step/sec: 6.954
# INFO:tensorflow:loss = 0.33484346, step = 84800 (14.376 sec)
# INFO:tensorflow:lr = 0.00012345625 (14.376 sec)
# INFO:tensorflow:global_step/sec: 7.19625
# INFO:tensorflow:loss = 0.18172854, step = 84900 (13.894 sec)
# INFO:tensorflow:lr = 0.00012328524 (13.898 sec)
# INFO:tensorflow:global_step/sec: 7.21898
# INFO:tensorflow:loss = 0.46995613, step = 85000 (13.851 sec)
# INFO:tensorflow:lr = 0.00012311446 (13.850 sec)
# INFO:tensorflow:global_step/sec: 7.05555
# INFO:tensorflow:loss = 0.28084585, step = 85100 (14.180 sec)
# INFO:tensorflow:lr = 0.0001229439 (14.176 sec)
# INFO:tensorflow:global_step/sec: 7.19107
# INFO:tensorflow:loss = 0.4453162, step = 85200 (13.908 sec)
# INFO:tensorflow:lr = 0.00012277358 (13.908 sec)
# INFO:tensorflow:global_step/sec: 7.12702
# INFO:tensorflow:loss = 0.5292616, step = 85300 (14.026 sec)
# INFO:tensorflow:lr = 0.00012260348 (14.027 sec)
# INFO:tensorflow:global_step/sec: 7.1586
# INFO:tensorflow:loss = 0.35241506, step = 85400 (13.967 sec)
# INFO:tensorflow:lr = 0.00012243363 (13.968 sec)
# INFO:tensorflow:global_step/sec: 6.94598
# INFO:tensorflow:loss = 0.38752398, step = 85500 (14.402 sec)
# INFO:tensorflow:lr = 0.00012226403 (14.401 sec)
# INFO:tensorflow:global_step/sec: 7.09519
# INFO:tensorflow:loss = 0.68464357, step = 85600 (14.095 sec)
# INFO:tensorflow:lr = 0.00012209466 (14.094 sec)
# INFO:tensorflow:global_step/sec: 6.9825
# INFO:tensorflow:loss = 0.24204227, step = 85700 (14.318 sec)
# INFO:tensorflow:lr = 0.00012192549 (14.322 sec)
# INFO:tensorflow:global_step/sec: 7.07341
# INFO:tensorflow:loss = 0.2988754, step = 85800 (14.138 sec)
# INFO:tensorflow:lr = 0.00012175661 (14.136 sec)
# Reading ../data/train.txt
# INFO:tensorflow:global_step/sec: 0.870441
# INFO:tensorflow:loss = 0.43979645, step = 85900 (114.881 sec)
# INFO:tensorflow:lr = 0.00012158793 (114.882 sec)
# INFO:tensorflow:Saving checkpoints for 85950 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-06:04:17
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-85950
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-06:04:28
# INFO:tensorflow:Saving dict for global step 85950: acc = 0.8726588, global_step = 85950, loss = 0.345553
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 85950: ../model/esim/model.ckpt-85950
# INFO:tensorflow:global_step/sec: 3.59648
# INFO:tensorflow:loss = 0.16434798, step = 86000 (27.810 sec)
# INFO:tensorflow:lr = 0.0001214195 (27.815 sec)
# INFO:tensorflow:global_step/sec: 7.02839
# INFO:tensorflow:loss = 0.26141322, step = 86100 (14.227 sec)
# INFO:tensorflow:lr = 0.00012125127 (14.222 sec)
# INFO:tensorflow:global_step/sec: 6.92761
# INFO:tensorflow:loss = 0.20115706, step = 86200 (14.429 sec)
# INFO:tensorflow:lr = 0.00012108331 (14.434 sec)
# INFO:tensorflow:global_step/sec: 6.99156
# INFO:tensorflow:loss = 0.27504855, step = 86300 (14.308 sec)
# INFO:tensorflow:lr = 0.00012091557 (14.302 sec)
# INFO:tensorflow:global_step/sec: 6.81893
# INFO:tensorflow:loss = 0.24552228, step = 86400 (14.662 sec)
# INFO:tensorflow:lr = 0.00012074805 (14.661 sec)
# INFO:tensorflow:global_step/sec: 7.08421
# INFO:tensorflow:loss = 0.381607, step = 86500 (14.118 sec)
# INFO:tensorflow:lr = 0.00012058078 (14.119 sec)
# INFO:tensorflow:global_step/sec: 6.93502
# INFO:tensorflow:loss = 0.5068438, step = 86600 (14.414 sec)
# INFO:tensorflow:lr = 0.000120413744 (14.414 sec)
# INFO:tensorflow:global_step/sec: 7.11612
# INFO:tensorflow:loss = 0.26888674, step = 86700 (14.060 sec)
# INFO:tensorflow:lr = 0.00012024693 (14.059 sec)
# INFO:tensorflow:global_step/sec: 7.0178
# INFO:tensorflow:loss = 0.20863585, step = 86800 (14.246 sec)
# INFO:tensorflow:lr = 0.00012008034 (14.246 sec)
# INFO:tensorflow:global_step/sec: 7.0753
# INFO:tensorflow:loss = 0.3247866, step = 86900 (14.131 sec)
# INFO:tensorflow:lr = 0.000119913995 (14.132 sec)
# INFO:tensorflow:global_step/sec: 7.10726
# INFO:tensorflow:loss = 0.3047887, step = 87000 (14.073 sec)
# INFO:tensorflow:lr = 0.00011974786 (14.072 sec)
# INFO:tensorflow:global_step/sec: 7.26736
# INFO:tensorflow:loss = 0.12225089, step = 87100 (13.769 sec)
# INFO:tensorflow:lr = 0.000119581986 (13.772 sec)
# INFO:tensorflow:global_step/sec: 7.02546
# INFO:tensorflow:loss = 0.32448533, step = 87200 (14.227 sec)
# INFO:tensorflow:lr = 0.000119416305 (14.223 sec)
# INFO:tensorflow:global_step/sec: 6.98915
# INFO:tensorflow:loss = 0.18326823, step = 87300 (14.303 sec)
# INFO:tensorflow:lr = 0.00011925089 (14.302 sec)
# INFO:tensorflow:global_step/sec: 7.01751
# INFO:tensorflow:loss = 0.460832, step = 87400 (14.250 sec)
# INFO:tensorflow:lr = 0.00011908569 (14.254 sec)
# INFO:tensorflow:global_step/sec: 7.21664
# INFO:tensorflow:loss = 0.34491625, step = 87500 (13.856 sec)
# INFO:tensorflow:lr = 0.0001189207 (13.854 sec)
# INFO:tensorflow:global_step/sec: 7.23247
# INFO:tensorflow:loss = 0.18201503, step = 87600 (13.833 sec)
# INFO:tensorflow:lr = 0.00011875596 (13.834 sec)
# INFO:tensorflow:Saving checkpoints for 87669 into ../model/esim/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-06:08:34
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-87669
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-06:08:46
# INFO:tensorflow:Saving dict for global step 87669: acc = 0.8726588, global_step = 87669, loss = 0.34648305
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 87669: ../model/esim/model.ckpt-87669
# INFO:tensorflow:No decrease in metric "loss" for 12033 steps, which is greater than or equal to max steps (12033) configured for early stopping.
# INFO:tensorflow:Requesting early stopping at global step 87669
# INFO:tensorflow:Saving checkpoints for 87670 into ../model/esim/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (60 secs).
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-31-06:08:49
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/esim/model.ckpt-87670
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Reading ../data/test.txt
# INFO:tensorflow:Finished evaluation at 2019-01-31-06:09:01
# INFO:tensorflow:Saving dict for global step 87670: acc = 0.872557, global_step = 87670, loss = 0.3463851
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 87670: ../model/esim/model.ckpt-87670
# INFO:tensorflow:Loss for final step: 0.118940726.
# ({'acc': 0.872557, 'global_step': 87670, 'loss': 0.3463851}, [])
